# %% [markdown]
# <a href="https://colab.research.google.com/github/ntandomkize007-svg/Chemical-Engineering-Portfolio/blob/main/Mass_Balance_Solver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True
    try
       input1=float(input(Input:1 is {}kg/mol))
